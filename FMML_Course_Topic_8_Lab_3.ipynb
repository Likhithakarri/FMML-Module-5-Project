# %% [markdown]
# <a href="https://colab.research.google.com/github/Likhithakarri/FMML-Module-5-Project/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-31 11:22:03--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.111.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   280MB/s    in 0.2s
#
# 2024-03-31 11:22:03 (280 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 10  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 25383  1508.02977v1  We consider a variational method to solve the ...    cs
# 26845  1701.00142v1  Marker-based and marker-less optical skeletal ...    cs
# 27859  1704.07296v1  In this project, we design a real-time human-c...    cs
# 5893    1212.2491v1  We present and implement two algorithms for an...    cs
# 27169  1702.06257v1  Deep convolutional networks are well-known for...    cs
# ...             ...                                                ...   ...
# 9372   1602.04358v1  In this paper we construct a learning architec...    cs
# 19109   1304.1118v1  This paper discusses how a measure of uncertai...    cs
# 2493    1311.3368v1  Belief Propagation has been widely used for ma...  stat
# 28911  1708.00251v1  Due to the increasing availability of whole sl...    cs
# 40936   1307.1394v1  Adverse drug reaction (ADR) is widely concerne...    cs
#
#                                                    title  year  \
# 25383  A massively parallel multi-level approach to a...  2015
# 26845  EgoCap: Egocentric Marker-less Motion Capture ...  2016
# 27859  A Real-time Hand Gesture Recognition and Human...  2017
# 5893   Automated Analytic Asymptotic Evaluation of th...  2012
# 27169  The Power of Sparsity in Convolutional Neural ...  2017
# ...                                                  ...   ...
# 9372   Machine olfaction using time scattering of sen...  2016
# 19109  Updating with Belief Functions, Ordinal Condit...  2013
# 2493     Anytime Belief Propagation Using Sparse Domains  2013
# 28911  CNN Cascades for Segmenting Whole Slide Images...  2017
# 40936  Detect adverse drug reactions for drug Alendro...  2013
#
#                                                 keywords
# 25383  [variational, illumination, regularization, co...
# 26845  [arrangement, constrained, backgrounds, lightw...
# 27859  [interaction, recognition, interaction, recogn...
# 5893   [particularly, approximation, difficulties, di...
# 27169  [convolutional, computational, surprisingly, c...
# ...                                                  ...
# 9372   [architecture, dimensional, arrangements, deco...
# 19109  [uncertainty, representing, information, uncer...
# 2493   [propagation, approximations, approximation, i...
# 28911  [availability, facilitating, digitization, his...
# 40936  [experiments, simvastatin, performance, comput...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 25383    [variational, illumination, regularization, co...
# 26845    [arrangement, constrained, backgrounds, lightw...
# 27859    [interaction, recognition, interaction, recogn...
# 5893     [particularly, approximation, difficulties, di...
# 27169    [convolutional, computational, surprisingly, c...
#                                ...
# 3693     [applications, contributions, contributed, per...
# 1640     [representations, applications, representation...
# 18802    [incorporate, uncertainty, incorporating, char...
# 27491    [generalization, contributions, associating, i...
# 23147    [recognition, approximation, conditional, alte...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 4407 words.
# Out of those 2043 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="def5fcc3-f8fa-4a88-ac65-87cbfcf617ad" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("def5fcc3-f8fa-4a88-ac65-87cbfcf617ad")) {                    Plotly.newPlot(                        "def5fcc3-f8fa-4a88-ac65-87cbfcf617ad",                        [{"x":["computations","decomposition","regularization","variational","parallelism","illumination","simulations","overlapping","arrangement","constrained","automatically","lightweight","backgrounds","recognition","interaction","specifically","reliability","convolutional","approximation","dimensionality","computation","particularly","difficulties","approximations","demonstrated","implemented","surprisingly","significantly","empirically","computational","architectures","convolution","connections","furthermore","representations","complicated","applications","substantially","recognizing","responsible","outperforms","abbreviation","experiments","distribution","information","application","traditional","unavailability","conservative","optimization","uncertainty","challenging","regularized","evolutionary","inappropriate","determining","acquisition","granularity","probabilistic","polylogarithmic","combination","generalization","approximate","accelerated","performance","compositional","discriminative","supervision","iteratively","construction","conventional","interesting","demonstrate","exemplified","selectivity","reconstructed","independent","probability","autoencoders","classifiers","distributed","autoencoder","constraints","experimental","incorporation","incorporating","incorporate","significant","equivalence","considering","eigenvector","transformation","perspective","consideration","accomplished","descriptions","investigate","identification","description","annotations","corroborate","efficiently","characterize","significance","theoretical","effectiveness","enhancements","contribution","hierarchical","variability","competitive","encouraging","consequences","counterpart","expectation","programming","maximization","dimensional","correctness","intelligence","neuroimaging","architecture","requirement","informative","limitations","experimentation","classification","initialized","developments","conjectured","reconstruction","statistical","semidefinite","representative","distinctive","similarities","containment","improvements","resemblance","systematically","adversarial","understanding","perturbations","consequently","transferability","constructing","hypothesize","unsupervised","discriminator","predictions","explanatory","interpreting","computationally","interpretable","environments","technologies","accessibility","interactive","traditionally","opportunities","implementation","researchers","eliminating","environment","conditional","personalized","formulation","quantization","compression","representation","abstraction","distinguishes","introduction","sensitivity","investigation","forecasting","legislative","alternatively","unprecedented","constitutes","prohibitive","introducing","heterogeneous","methodologies","multispectral","frequencies","illustrated","analytically","parameterization","contributions","orthonormal","extensively","associative","propagation","relationship","hyperparameter","hyperparameters","implementations","additionally","requirements"],"y":[35,76,85,57,15,33,43,19,8,53,171,12,8,385,93,153,26,380,134,60,163,87,29,36,88,127,35,291,75,307,123,40,52,156,243,33,470,41,46,4,258,3,635,222,688,247,164,1,4,315,83,264,36,60,1,31,47,16,150,2,130,109,94,15,872,26,107,58,31,82,115,62,610,3,6,21,144,184,21,112,103,33,147,373,12,62,64,254,26,67,4,82,72,24,11,28,140,96,72,69,4,164,48,18,161,211,2,70,106,25,114,26,21,16,29,118,27,209,20,104,6,228,33,49,60,12,499,12,20,4,114,155,8,41,12,3 ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (2043,), (2043, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.77

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Neighbors</span> <span style=''>Do</span> <span style=''>Help</span> <span style=''>Deeply</span> <span style=''>Exploiting</span> <span style=''>Local</span> <span style=''>Structures</span> <span style=''>of</span> <span style=''>Point</span> <span style=''>Clouds</span> <br/><br/><span style=''>Unlike</span> <span style=''>on</span> <span style=''>images</span> <span style=''>semantic</span> <span style=''>learning</span> <span style=''>on</span> <span style=''>3D</span> <span style=''>point</span> <span style=''>clouds</span> <span style=''>using</span> <span style=''>a</span> <span style=''>deep</span> <span style=''>network</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3968253968253968);'>challenging</span> <span style=''>due</span> <span style=''>to</span> <span style=''>the</span> <span style=''>naturally</span> <span style=''>unordered</span> <span style=''>data</span> <span style=''>structure</span> <span style=''>Among</span> <span style=''>existing</span> <span style=''>works</span> <span style=''>PointNet</span> <span style=''>has</span> <span style=''>achieved</span> <span style=''>promising</span> <span style=''>results</span> <span style=''>by</span> <span style=''>directly</span> <span style=''>learning</span> <span style=''>on</span> <span style=''>point</span> <span style=''>sets</span> <span style=''>However</span> <span style=''>it</span> <span style=''>does</span> <span style=''>not</span> <span style=''>take</span> <span style=''>full</span> <span style=''>advantage</span> <span style=''>of</span> <span style=''>a</span> <span style=''>points</span> <span style=''>local</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>neighborhood</span> <span style=''>that</span> <span style=''>contains</span> <span style=''>fine</span> <span style=''>grained</span> <span style=''>structural</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>information</span> <span style=''>which</span> <span style=''>turns</span> <span style=''>out</span> <span style=''>to</span> <span style=''>be</span> <span style=''>helpful</span> <span style=''>towards</span> <span style=''>better</span> <span style=''>semantic</span> <span style=''>learning</span> <span style=''>In</span> <span style=''>this</span> <span style=''>regard</span> <span style=''>we</span> <span style=''>present</span> <span style=''>two</span> <span style=''>new</span> <span style=''>operations</span> <span style=''>to</span> <span style=''>improve</span> <span style=''>PointNet</span> <span style=''>with</span> <span style=''>more</span> <span style=''>efficient</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>exploitation</span> <span style=''>of</span> <span style=''>local</span> <span style=''>structures</span> <span style=''>The</span> <span style=''>first</span> <span style=''>one</span> <span style=''>focuses</span> <span style=''>on</span> <span style=''>local</span> <span style=''>3D</span> <span style=''>geometric</span> <span style=''>structures</span> <span style=''>In</span> <span style=''>analogy</span> <span style=''>with</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.4545454545454545);'>convolution</span> <span style=''>kernel</span> <span style=''>for</span> <span style=''>images</span> <span style=''>we</span> <span style=''>define</span> <span style=''>a</span> <span style=''>point</span> <span style=''>set</span> <span style=''>kernel</span> <span style=''>as</span> <span style=''>a</span> <span style=''>set</span> <span style=''>of</span> <span style=''>learnable</span> <span style=''>points</span> <span style=''>that</span> <span style=''>jointly</span> <span style=''>respond</span> <span style=''>to</span> <span style=''>a</span> <span style=''>set</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.6666666666666666);'>neighboring</span> <span style=''>data</span> <span style=''>points</span> <span style='' ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Support</span> <span style=''>Vector</span> <span style=''>Machines</span> <span style=''>for</span> <span style=''>Additive</span> <span style=''>Models</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Consistency</span> <span style=''>and</span> <span style=''>Robustness</span> <br/><br/><span style=''>Support</span> <span style=''>vector</span> <span style=''>machines</span> <span style=''>(SVMs)</span> <span style=''>are</span> <span style=''>special</span> <span style=''>kernel</span> <span style=''>based</span> <span style=''>methods</span> <span style=''>and</span> <span style=''>belong</span> <span style=''>to</span> <span style=''>the</span> <span style=''>most</span> <span style=''>successful</span> <span style=''>learning</span> <span style=''>methods</span> <span style=''>since</span> <span style=''>more</span> <span style=''>than</span> <span style=''>a</span> <span style=''>decade</span> <span style=''>SVMs</span> <span style=''>can</span> <span style=''>informally</span> <span style=''>be</span> <span style=''>described</span> <span style=''>as</span> <span style=''>a</span> <span style=''>kind</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regularized</span> <span style=''>M</span> <span style=''>estimators</span> <span style=''>for</span> <span style=''>functions</span> <span style=''>and</span> <span style=''>have</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>demonstrated</span> <span style=''>their</span> <span style=''>usefulness</span> <span style=''>in</span> <span style=''>many</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>complicated</span> <span style=''>real</span> <span style=''>life</span> <span style=''>problems</span> <span style=''>During</span> <span style=''>the</span> <span style=''>last</span> <span style=''>years</span> <span style=''>a</span> <span style=''>great</span> <span style=''>part</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistical</span> <span style=''>research</span> <span style=''>on</span> <span style=''>SVMs</span> <span style=''>has</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>concentrated</span> <span style=''>on</span> <span style=''>the</span> <span style=''>question</span> <span style=''>how</span> <span style=''>to</span> <span style=''>design</span> <span style=''>SVMs</span> <span style=''>such</span> <span style=''>that</span> <span style=''>they</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>universally</span> <span style=''>consistent</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistically</span> <span style=''>robust</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>nonparametric</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style=''>or</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>nonparametric</span> <span style=''>regression</span> <span style=''>purposes</span> <span style=''>In</span> <span style=''>many</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>applications</span> <span style=''>some</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>qualitative</span> <span style=''>prior</span> <span style=''>knowledge</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distribution</span> <span style=''>P</span> <span style=''>or</span> <span style=''>of</span> <span style=''>the</span> <span style=''>unknown</span> <span style=''>function</span> <span style=''>f</span> <span style=''>to</span> <span style=''>be</span> <span style=''>estimated</span> <span style=''>is</span> <span style=''>present</span> <span style=''>or</span> <span style=''>the</span> <span style=''>prediction</span> <span style=''>function</span> <span style=''>with</span ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Generating</span> <span style=''>Sentences</span> <span style=''>by</span> <span style=''>Editing</span> <span style=''>Prototypes</span> <br/><br/><span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>new</span> <span style=''>generative</span> <span style=''>model</span> <span style=''>of</span> <span style=''>sentences</span> <span style=''>that</span> <span style=''>first</span> <span style=''>samples</span> <span style=''>a</span> <span style=''>prototype</span> <span style=''>sentence</span> <span style=''>from</span> <span style=''>the</span> <span style=''>training</span> <span style=''>corpus</span> <span style=''>and</span> <span style=''>then</span> <span style=''>edits</span> <span style=''>it</span> <span style=''>into</span> <span style=''>a</span> <span style=''>new</span> <span style=''>sentence</span> <span style=''>Compared</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3067729083665338);'>traditional</span> <span style=''>models</span> <span style=''>that</span> <span style=''>generate</span> <span style=''>from</span> <span style=''>scratch</span> <span style=''>either</span> <span style=''>left</span> <span style=''>to</span> <span style=''>right</span> <span style=''>or</span> <span style=''>by</span> <span style=''>first</span> <span style=''>sampling</span> <span style=''>a</span> <span style=''>latent</span> <span style=''>sentence</span> <span style=''>vector</span> <span style=''>our</span> <span style=''>prototype</span> <span style=''>then</span> <span style=''>edit</span> <span style=''>model</span> <span style=''>improves</span> <span style=''>perplexity</span> <span style=''>on</span> <span style=''>language</span> <span style=''>modeling</span> <span style=''>and</span> <span style=''>generates</span> <span style=''>higher</span> <span style=''>quality</span> <span style=''>outputs</span> <span style=''>according</span> <span style=''>to</span> <span style=''>human</span> <span style=''>evaluation</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Furthermore</span> <span style=''>the</span> <span style=''>model</span> <span style=''>gives</span> <span style=''>rise</span> <span style=''>to</span> <span style=''>a</span> <span style=''>latent</span> <span style=''>edit</span> <span style=''>vector</span> <span style=''>that</span> <span style=''>captures</span> <span style='background-color:rgba(255, 0, 0, 0.4414414414414414);'>interpretable</span> <span style=''>semantics</span> <span style=''>such</span> <span style=''>as</span> <span style=''>sentence</span> <span style=''>similarity</span> <span style=''>and</span> <span style=''>sentence</span> <span style=''>level</span> <span style=''>analogies</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Random</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>projections</span> <span style=''>of</span> <span style=''>random</span> <span style=''>manifolds</span> <br/><br/><span style='background-color:rgba(255, 0, 0, 0.3);'>Interesting</span> <span style=''>data</span> <span style=''>often</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>concentrate</span> <span style=''>on</span> <span style=''>low</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style=''>smooth</span> <span style=''>manifolds</span> <span style=''>inside</span> <span style=''>a</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style=''>ambient</span> <span style=''>space</span> <span style=''>Random</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>projections</span> <span style=''>are</span> <span style=''>a</span> <span style=''>simple</span> <span style=''>powerful</span> <span style=''>tool</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensionality</span> <span style=''>reduction</span> <span style=''>of</span> <span style=''>such</span> <span style=''>data</span> <span style=''>Previous</span> <span style=''>works</span> <span style=''>have</span> <span style=''>studied</span> <span style=''>bounds</span> <span style=''>on</span> <span style=''>how</span> <span style=''>many</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>projections</span> <span style=''>are</span> <span style=''>needed</span> <span style=''>to</span> <span style=''>accurately</span> <span style=''>preserve</span> <span style=''>the</span> <span style=''>geometry</span> <span style=''>of</span> <span style=''>these</span> <span style=''>manifolds</span> <span style=''>given</span> <span style=''>their</span> <span style=''>intrinsic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensionality</span> <span style=''>volume</span> <span style=''>and</span> <span style=''>curvature</span> <span style=''>However</span> <span style=''>such</span> <span style=''>works</span> <span style=''>employ</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>definitions</span> <span style=''>of</span> <span style=''>volume</span> <span style=''>and</span> <span style=''>curvature</span> <span style=''>that</span> <span style=''>are</span> <span style=''>inherently</span> <span style=''>difficult</span> <span style=''>to</span> <span style=''>compute</span> <span style=''>Therefore</span> <span style=''>such</span> <span style=''>theory</span> <span style=''>cannot</span> <span style=''>be</span> <span style=''>easily</span> <span style=''>tested</span> <span style=''>against</span> <span style=''>numerical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>simulations</span> <span style=''>to</span> <span style=''>understand</span> <span style=''>the</span> <span style=''>tightness</span> <span style=''>of</span> <span style=''>the</span> <span style=''>proven</span> <span style=''>bounds</span> <span style=''>We</span> <span style=''>instead</span> <span style=''>study</span> <span style=''>typical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distortions</span> <span style=''>arising</span> <span style=''>in</span> <span style=''>random</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>projections</span> <span style=''>of</span> <span style=''>an</span> <span style=''>ensemble</span> <span style=''>of</span> <span style=''>smooth</span> <span style=''>Gaussian</span> <span style=''>random</span> <span style=''>manifolds</span> <span style=''>We</span> <span style=''>find</span> <span style=''>explicitly</span> <span style=''>computable</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximate</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>theoretical</span> <span style=''>bounds</span> <span style=''>on</span> <span style=''> ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	intelligence (0.03701067615658363)
# 	representations (0.08647686832740213)
# 	challenging (0.09395017793594305)
# 	experimental (0.13274021352313167)
# 	representation (0.12740213523131672)
# 	architecture (0.08113879003558719)
# 	segmentation (0.0701067615658363)
# 	information (0.24483985765124555)
# 	convolutional (0.13523131672597866)
# 	recognition (0.13701067615658363)
#
# Some Statistics words are:
# 	approximation (0.10251256281407035)
# 	regularization (0.0914572864321608)
# 	optimization (0.1849246231155779)
# 	distributions (0.11809045226130653)
# 	variational (0.1)
# 	convergence (0.1321608040201005)
# 	statistical (0.1577889447236181)
# 	theoretical (0.16180904522613065)
# 	distribution (0.1849246231155779)
# 	dimensional (0.18944723618090453)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="9b25c65e-9ced-4fa6-a0b5-27e3c7b44111" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9b25c65e-9ced-4fa6-a0b5-27e3c7b44111")) {                    Plotly.newPlot(                        "9b25c65e-9ced-4fa6-a0b5-27e3c7b44111",                        [{"x":["computations","decomposition","regularization","variational","parallelism","illumination","simulations","overlapping","arrangement","constrained","automatically","lightweight","backgrounds","recognition","interaction","specifically","reliability","convolutional","approximation","dimensionality","computation","particularly","difficulties","approximations","demonstrated","implemented","surprisingly","significantly","empirically","computational","architectures","convolution","connections","furthermore","representations","complicated","applications","substantially","recognizing","responsible","outperforms","abbreviation","experiments","distribution","information","application","traditional","unavailability","conservative","optimization","uncertainty","challenging","regularized","evolutionary","inappropriate","determining","acquisition","granularity","probabilistic","polylogarithmic","combination","generalization","approximate","accelerated","performance","compositional","discriminative","supervision","iteratively","construction","conventional","interesting","demonstrate","exemplified","selectivity","reconstructed","independent","probability","autoencoders","classifiers","distributed","autoencoder","constraints","experimental","incorporation","incorporating","incorporate","significant","equivalence","considering","eigenvector","transformation","perspective","consideration","accomplished","descriptions","investigate","identification","description","annotations","corroborate","efficiently","characterize","significance","theoretical","effectiveness","enhancements","contribution","hierarchical","variability","competitive","encouraging","consequences","counterpart","expectation","programming","maximization","dimensional","correctness","intelligence","neuroimaging","architecture","requirement","informative","limitations","experimentation","classification","initialized","developments","conjectured","reconstruction","statistical","semidefinite","representative","distinctive","similarities","containment","improvements","resemblance","systematically","adversarial","understanding","perturbations","consequently","transferability","constructing","hypothesize","unsupervised","discriminator","predictions","explanatory","interpreting","computationally","interpretable","environments","technologies","accessibility","interactive","traditionally","opportunities","implementation","researchers","eliminating","environment","conditional","personalized","formulation","quantization","compression","representation","abstraction","distinguishes","introduction","sensitivity","investigation","forecasting","legislative","alternatively","unprecedented","constitutes","prohibitive","introducing","heterogeneous","methodologies","multispectral","frequencies","illustrated","analytically","parameterization","contributions","orthonormal","extensively","associative","propagation","relationship","hyperparameter","hyperparameters","implementations","additionally","requirements","opportunity","consumption","compositing","evaluations","quantitative","qualitative","exclusively","alternative","simultaneously","regularizer","distinguish","individuals","convergence","considerable","transferring","compensating","infrequently","correlations","assignments","generalized","effectively","unfavorable","facilitates","intractable","coefficient","conveniently","reconstructions","coefficients","development","independence","proport ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	instantiating
# 	judiciously
# 	epigenomics
# 	deteriorates
# 	asymptotics
# 	nonconvexity
# 	unnormalized
# 	prognostics
# 	bhattacharya
# 	organisation
# 	frequentist
# 	nonparametrics
# 	discriminates
# 	discounting
# 	assimilation
# 	percolation
# 	manufacturability
# 	uncontaminated
# 	uncollapsed
# 	memberships
# Some words which never appear in Statistics papers:
# 	illumination
# 	abbreviation
# 	exemplified
# 	multispectral
# 	compositing
# 	infrequently
# 	subsumption
# 	stylometric
# 	categorised
# 	synthesizers
# 	counterexamples
# 	checkerboard
# 	interconnected
# 	responsibility
# 	lukasiewicz
# 	alternatingly
# 	supervoxels
# 	perceptions
# 	differentiate
# 	disparities

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.3175198221809375e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7525
